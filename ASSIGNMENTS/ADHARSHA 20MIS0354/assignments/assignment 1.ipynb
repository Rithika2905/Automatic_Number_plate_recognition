# %%
import pandas as pd
import numpy as np

# %%
# Task1
ser_1 = pd.Series(np.random.rand(4))
print(ser_1)
ser_2 = pd.Series(np.random.rand(4))
print(ser_2)
ser_3 = pd.Series(np.random.rand(4))
print(ser_3)
ser_4 = pd.Series(np.random.rand(4))
print(ser_4)
df = pd.DataFrame([ser_1,ser_2,ser_3,ser_4])
df
# Out:
# 0    0.600985
# 1    0.281716
# 2    0.385319
# 3    0.865825
# dtype: float64
# 0    0.124539
# 1    0.509561
# 2    0.701286
# 3    0.754086
# dtype: float64
# 0    0.641344
# 1    0.868803
# 2    0.121145
# 3    0.850960
# dtype: float64
# 0    0.435736
# 1    0.794390
# 2    0.850676
# 3    0.779157
# dtype: float64
#           0         1         2         3
# 0  0.600985  0.281716  0.385319  0.865825
# 1  0.124539  0.509561  0.701286  0.754086
# 2  0.641344  0.868803  0.121145  0.850960
# 3  0.435736  0.794390  0.850676  0.779157

# %%
# Task2

df.columns =['Random value 1', 'Random value 2', 'Random value 3','Random value 4']
df
# Out:
#    Random value 1  Random value 2  Random value 3  Random value 4
# 0        0.600985        0.281716        0.385319        0.865825
# 1        0.124539        0.509561        0.701286        0.754086
# 2        0.641344        0.868803        0.121145        0.850960
# 3        0.435736        0.794390        0.850676        0.779157

# %%
# Task 3

df.describe()
# Out:
#        Random value 1  Random value 2  Random value 3  Random value 4
# count        4.000000        4.000000        4.000000        4.000000
# mean         0.450651        0.613617        0.514606        0.812507
# std          0.234901        0.270052        0.326251        0.054303
# min          0.124539        0.281716        0.121145        0.754086
# 25%          0.357937        0.452600        0.319275        0.772890
# 50%          0.518361        0.651975        0.543302        0.815058
# 75%          0.611075        0.812993        0.738633        0.854676
# max          0.641344        0.868803        0.850676        0.865825

# %%
df.describe(include='all')
# Out:
#        Random value 1  Random value 2  Random value 3  Random value 4
# count        4.000000        4.000000        4.000000        4.000000
# mean         0.450651        0.613617        0.514606        0.812507
# std          0.234901        0.270052        0.326251        0.054303
# min          0.124539        0.281716        0.121145        0.754086
# 25%          0.357937        0.452600        0.319275        0.772890
# 50%          0.518361        0.651975        0.543302        0.815058
# 75%          0.611075        0.812993        0.738633        0.854676
# max          0.641344        0.868803        0.850676        0.865825

# %%
# Task 4

df['Random value 4']=[0.231572,np.NaN,0.955167,0.244768]
df
# Out:
#    Random value 1  Random value 2  Random value 3  Random value 4
# 0        0.600985        0.281716        0.385319        0.231572
# 1        0.124539        0.509561        0.701286             NaN
# 2        0.641344        0.868803        0.121145        0.955167
# 3        0.435736        0.794390        0.850676        0.244768

# %%
df.isnull()
# Out:
#    Random value 1  Random value 2  Random value 3  Random value 4
# 0           False           False           False           False
# 1           False           False           False            True
# 2           False           False           False           False
# 3           False           False           False           False

# %%
df.isnull().sum()
# Out:
# Random value 1    0
# Random value 2    0
# Random value 3    0
# Random value 4    1
# dtype: int64

# %%
df['Random value 1'].dtype
# Out:
# dtype('float64')

# %%
df['Random value 2'].dtype
# Out:
# dtype('float64')

# %%
df['Random value 3'].dtype
# Out:
# dtype('float64')

# %%
df['Random value 4'].dtype
# Out:
# dtype('float64')

# %%
# Task5

df.loc[0:3,'Random value 2': 'Random value 3']
# Out:
#    Random value 2  Random value 3
# 0        0.281716        0.385319
# 1        0.509561        0.701286
# 2        0.868803        0.121145
# 3        0.794390        0.850676

# %%
df.iloc[0:,1:3]
# Out:
#    Random value 2  Random value 3
# 0        0.281716        0.385319
# 1        0.509561        0.701286
# 2        0.868803        0.121145
# 3        0.794390        0.850676
